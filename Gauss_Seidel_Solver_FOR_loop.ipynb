# %%
# Solving the system of linear equations using Gauss Seidel Method
# a1.x + b1.y + c1.z = d1 
# a2.x + b2.y + c2.z = d2
# a3.x + b3.y + c3.z = d3

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

x_values = np.array([])
y_values = np.array([])
z_values = np.array([])
iterations = np.array([])
def gauss_seidel_solver(a1,b1,c1,d1,a2,b2,c2,d2,a3,b3,c3,d3,e,n):
    x1 = 0;
    y1 = 0;
    z1 = 0;
    x = 0;
    y = 0;
    z = 0;
    global x_values;
    global y_values;
    global z_values;
    global iterations;
    if (a1 > b1 + c1 and b2 > a2 + c2 and c3 > a3 + b3):
        for i in range(1,n + 1):
            print("---------------------------Iteration No. ",i," ----------------------------")
            x1 = (1/a1)*(d1 - b1*y1 - c1*z1)
            y1 = (1/b2)*(d2 - a2*x1 - c2*z1)
            z1 = (1/c3)*(d3 - a3*x1 - b3*y1)
            if abs(x - x1) < e and abs(y - y1) < e and abs(z - z1) < e:
                print("Solution has converged!")
                break
            else:
                print("The value for x1 is: ",x1)
                print("The value for y1 is: ",y1)
                print("The value for z1 is: ",z1)
            x = x1
            y = y1
            z = z1
            x_values = np.append(x_values,x1)
            y_values = np.append(y_values,y1)
            z_values = np.append(z_values,z1)
            iterations = np.append(iterations,i)
        print("The System of equations has been solved!\n")
        print("The value for x is: ", round(x1,2))
        print("The value for y is: ", round(y1,2))
        print("The value for z is: ", round(z1,2),"\n\n")
        print("------------------------------Residual Plot ---------------------------------\n")
        plt.plot(iterations,x_values, label = "x")
        plt.plot(iterations,y_values, label = "y")
        plt.plot(iterations,z_values, label = "z")
        plt.legend(loc = 1)
        
    else:
        print("The given system of equations are not strongly diagonally dominant, which ensures the divergence of approximations.")

a1 = float(input("Enter the value of a1: "))
b1 = float(input("Enter the value of b1: "))
c1 = float(input("Enter the value of c1: "))
d1 = float(input("Enter the value of d1: "))
a2 = float(input("Enter the value of a2: "))
b2 = float(input("Enter the value of b2: "))
c2 = float(input("Enter the value of c2: "))
d2 = float(input("Enter the value of d2: "))
a3 = float(input("Enter the value of a3: "))
b3 = float(input("Enter the value of b3: "))
c3 = float(input("Enter the value of c3: "))
d3 = float(input("Enter the value of d3: "))
e = float(input("Enter the value of tolerable error(e): "))
n = int(input("Enter the value of n iterations: "))
gauss_seidel_solver(a1,b1,c1,d1,a2,b2,c2,d2,a3,b3,c3,d3,e,n)
# Out:
# Enter the value of a1: 23
# Enter the value of b1: 2
# Enter the value of c1: 2
# Enter the value of d1: 45
# Enter the value of a2: 3
# Enter the value of b2: 17
# Enter the value of c2: 5
# Enter the value of d2: 27
# Enter the value of a3: 2
# Enter the value of b3: 5
# Enter the value of c3: 25
# Enter the value of d3: 63
# Enter the value of tolerable error(e): 0.00001
# Enter the value of n iterations: 50
# ---------------------------Iteration No.  1  ----------------------------
# The value for x1 is:  1.9565217391304348
# The value for y1 is:  1.2429667519181586
# The value for z1 is:  2.1148849104859333
# ---------------------------Iteration No.  2  ----------------------------
# The value for x1 is:  1.6645346380518182
# The value for y1 is:  0.672468913730287
# The value for z1 is:  2.252343446209797
# ---------------------------Iteration No.  3  ----------------------------
# The value for x1 is:  1.7021902295704274
# The value for y1 is:  0.6253948282493961
# The value for z1 is:  2.2587458159844864
# ---------------------------Iteration No.  4  ----------------------------
# The value for x1 is:  1.7057269005014015
# The value for y1 is:  0.6228876599160803
# The value for z1 is:  2.258964315976672
# ---------------------------Iteration No.  5  ----------------------------
# The value for x1 is:  1.7059259151397606
# The value for y1 is:  0.6227882749821975
# The value for z1 is:  2.2589682717923796
# ---------------------------Iteration No.  6  ----------------------------
# Solution has converged!
# The System of equations has been solved!
#
# The value for x is:  1.71
# The value for y is:  0.62
# The value for z is:  2.26
#
#
# ------------------------------Residual Plot ---------------------------------
