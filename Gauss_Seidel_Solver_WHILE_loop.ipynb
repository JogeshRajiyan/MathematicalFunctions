# %%
# Solving the system of linear equations using Gauss Seidel Method
# a1.x + b1.y + c1.z = d1 
# a2.x + b2.y + c2.z = d2
# a3.x + b3.y + c3.z = d3

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

x_values_2 = np.array([])
y_values_2 = np.array([])
z_values_2 = np.array([])
iterations_2 = np.array([])
def gauss_seidel_solver2(a1,b1,c1,d1,a2,b2,c2,d2,a3,b3,c3,d3,n):
    x = 0;
    y = 0;
    z = 0;
    x1 = 0;
    y1 = 0;
    z1 = 0;
    e1 = 1;
    e2 = 1;
    e3 = 1;
    count = 1;
    global x_values_2;
    global y_values_2;
    global z_values_2;
    global iterations_2;
    if (a1 > b1 + c1 and b2 > a2 + c2 and c3 > a3 + b3):
        while e1 > n and e2 > n and e3 > n:
            print("---------------------------Iteration No. ",count," ----------------------------")
            count = count + 1
            x1 = (1/a1)*(d1 - b1*y1 - c1*z1)
            y1 = (1/b2)*(d2 - a2*x1 - c2*z1)
            z1 = (1/c3)*(d3 - a3*x1 - b3*y1)
            e1 = abs(x - x1)
            e2 = abs(y - y1)
            e3 = abs(z - z1)
            print("The value of x1: ", x1)
            print("The value of y1: ", y1)
            print("The value of z1: ", z1)
            x = x1
            y = y1
            z = z1
            x_values_2 = np.append(x_values_2,x1)
            y_values_2 = np.append(y_values_2,y1)
            z_values_2 = np.append(z_values_2,z1)
            iterations_2 = np.append(iterations_2,count)
        print("The solution has converged successfully!")
        print("The System of equations has been solved!\n")
        print("The value for x is: ", round(x1,2))
        print("The value for y is: ", round(y1,2))
        print("The value for z is: ", round(z1,2),"\n\n")
        print("------------------------------Residual Plot ---------------------------------\n")
        plt.plot(iterations_2,x_values_2, label = "x")
        plt.plot(iterations_2,y_values_2, label = "y")
        plt.plot(iterations_2,z_values_2, label = "z")
        plt.legend(loc = 1)
    else:
        print("The given system of equations are not strongly diagonally dominant, which ensures the divergence of approximations.")
    

a1 = float(input("Enter the value of a1: "))
b1 = float(input("Enter the value of b1: "))
c1 = float(input("Enter the value of c1: "))
d1 = float(input("Enter the value of d1: "))
a2 = float(input("Enter the value of a2: "))
b2 = float(input("Enter the value of b2: "))
c2 = float(input("Enter the value of c2: "))
d2 = float(input("Enter the value of d2: "))
a3 = float(input("Enter the value of a3: "))
b3 = float(input("Enter the value of b3: "))
c3 = float(input("Enter the value of c3: "))
d3 = float(input("Enter the value of d3: "))
n = float(input("Enter the tolerance value: "))
gauss_seidel_solver2(a1,b1,c1,d1,a2,b2,c2,d2,a3,b3,c3,d3,n)
# Out:
# Enter the value of a1: 23
# Enter the value of b1: 2
# Enter the value of c1: 2
# Enter the value of d1: 45
# Enter the value of a2: 3
# Enter the value of b2: 17
# Enter the value of c2: 5
# Enter the value of d2: 27
# Enter the value of a3: 2
# Enter the value of b3: 5
# Enter the value of c3: 25
# Enter the value of d3: 63
# Enter the tolerance value: 0.00001
# ---------------------------Iteration No.  1  ----------------------------
# The value of x1:  1.9565217391304348
# The value of y1:  1.2429667519181586
# The value of z1:  2.1148849104859333
# ---------------------------Iteration No.  2  ----------------------------
# The value of x1:  1.6645346380518182
# The value of y1:  0.672468913730287
# The value of z1:  2.252343446209797
# ---------------------------Iteration No.  3  ----------------------------
# The value of x1:  1.7021902295704274
# The value of y1:  0.6253948282493961
# The value of z1:  2.2587458159844864
# ---------------------------Iteration No.  4  ----------------------------
# The value of x1:  1.7057269005014015
# The value of y1:  0.6228876599160803
# The value of z1:  2.258964315976672
# ---------------------------Iteration No.  5  ----------------------------
# The value of x1:  1.7059259151397606
# The value of y1:  0.6227882749821975
# The value of z1:  2.2589682717923796
# The solution has converged successfully!
# The System of equations has been solved!
#
# The value for x is:  1.71
# The value for y is:  0.62
# The value for z is:  2.26
#
#
# ------------------------------Residual Plot ---------------------------------
